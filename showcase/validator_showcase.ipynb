# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from relbench.datasets.f1 import F1Dataset
from showcase_helper import ConverterShowcaseHelper

# %%
f1_dataset = F1Dataset()
timestamps = pd.date_range(start="2010-01-01", end="2010-05-05", freq="D")

db = f1_dataset.get_db(upto_test_timestamp=False)
temporal_helper = ConverterShowcaseHelper(db, timestamps)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# Done in 0.23 seconds.

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position WHERE standings.position == 1, -1, 10, days) > 10
                FOR EACH drivers.driverId 
                WHERE AVG(results.position, 10, 2, days) < 30;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position WHERE standings.position == 1, -1, 10, days) > 10
#                 FOR EACH drivers.driverId
#                 WHERE AVG(results.position, 10, 2, days) < 30;
# 1. ERROR at line 2:51 - Table 'standings' in condition is not connected to main table 'results'and main table 'results' is not connected to 'standings'
# 2. ERROR at line 2:76 - Start and end time in temporal aggregation must be non-negative in PREDICT and WHERE clauses, found start=-1.0, end=10.0
# 3. ERROR at line 4:44 - Start time must be less than end time in temporal aggregation, found start=10.0, end=2.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
