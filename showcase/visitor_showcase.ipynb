# %%
# %load_ext autoreload
# %autoreload 2

# %%
from showcase_helper import parse_query

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE NOT inf.age == 10;"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE NOT inf.age == 10;
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: inf (ID)
#   Terminal: . (DOT)
#   Terminal: age (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 10 (INT)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'CType': 'num', 'CompOp': '==', 'N': '10', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'inf', 'Column': 'age'}}}, 'Assuming': None, 'Where': None}
# ==================

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE inf.age IS NULL;"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE inf.age IS NULL;
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: inf (ID)
#   Terminal: . (DOT)
#   Terminal: age (ID)
#   Rule: null_check_condition
#   Terminal: IS NULL (NULL_CHECK_OP)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'CType': 'null', 'CheckOp': 'IS NULL', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'inf', 'Column': 'age'}}}, 'Assuming': None, 'Where': None}
# ==================

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE (NOT a.b == 10 AND c.d LIKE "e") OR NOT f.g IS NULL;"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE (NOT a.b == 10 AND c.d LIKE "e") OR NOT f.g IS NULL;
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Terminal: ( (OPEN_PAREN)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: a (ID)
#   Terminal: . (DOT)
#   Terminal: b (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 10 (INT)
#   Terminal: AND (AND)
#   Rule: expr_term
#   Rule: condition
#   Terminal: c (ID)
#   Terminal: . (DOT)
#   Terminal: d (ID)
#   Rule: str_condition
#   Terminal: LIKE (STR_COMP_OP)
#   Terminal: "e" (STRING)
#   Terminal: ) (CLOSE_PAREN)
#   Terminal: OR (OR)
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: f (ID)
#   Terminal: . (DOT)
#   Terminal: g (ID)
#   Rule: null_check_condition
#   Terminal: IS NULL (NULL_CHECK_OP)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'Op': 'OR', 'Left': {'Op': 'AND', 'Left': {'CType': 'num', 'CompOp': '==', 'N': '10', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'a', 'Column': 'b'}, 'Right': {'CType': 'str', 'CompOp': 'LIKE', 'String': '"e"', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'c', 'Column': 'd'}}, 'Right': {'CType': 'null', 'CheckOp': 'IS NULL', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'f', 'Column': 'g'}}}}, 'Assuming': None, 'Where': None}
# ==================

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE NOT a.b == 10 AND c.d LIKE "e" OR NOT f.g IS NULL;"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE NOT a.b == 10 AND c.d LIKE "e" OR NOT f.g IS NULL;
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: a (ID)
#   Terminal: . (DOT)
#   Terminal: b (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 10 (INT)
#   Terminal: AND (AND)
#   Rule: expr_term
#   Rule: condition
#   Terminal: c (ID)
#   Terminal: . (DOT)
#   Terminal: d (ID)
#   Rule: str_condition
#   Terminal: LIKE (STR_COMP_OP)
#   Terminal: "e" (STRING)
#   Terminal: OR (OR)
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: f (ID)
#   Terminal: . (DOT)
#   Terminal: g (ID)
#   Rule: null_check_condition
#   Terminal: IS NULL (NULL_CHECK_OP)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'Op': 'OR', 'Left': {'Op': 'AND', 'Left': {'CType': 'num', 'CompOp': '==', 'N': '10', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'a', 'Column': 'b'}, 'Right': {'CType': 'str', 'CompOp': 'LIKE', 'String': '"e"', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'c', 'Column': 'd'}}, 'Right': {'CType': 'null', 'CheckOp': 'IS NULL', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'f', 'Column': 'g'}}}}, 'Assuming': None, 'Where': None}
# ==================

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE NOT a.b == 10 AND (c.d LIKE "e" OR NOT f.g IS NULL);"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE NOT a.b == 10 AND (c.d LIKE "e" OR NOT f.g IS NULL);
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: a (ID)
#   Terminal: . (DOT)
#   Terminal: b (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 10 (INT)
#   Terminal: AND (AND)
#   Rule: expr_term
#   Terminal: ( (OPEN_PAREN)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: c (ID)
#   Terminal: . (DOT)
#   Terminal: d (ID)
#   Rule: str_condition
#   Terminal: LIKE (STR_COMP_OP)
#   Terminal: "e" (STRING)
#   Terminal: OR (OR)
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: f (ID)
#   Terminal: . (DOT)
#   Terminal: g (ID)
#   Rule: null_check_condition
#   Terminal: IS NULL (NULL_CHECK_OP)
#   Terminal: ) (CLOSE_PAREN)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'Op': 'AND', 'Left': {'CType': 'num', 'CompOp': '==', 'N': '10', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'a', 'Column': 'b'}, 'Right': {'Op': 'OR', 'Left': {'CType': 'str', 'CompOp': 'LIKE', 'String': '"e"', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'c', 'Column': 'd'}, 'Right': {'CType': 'null', 'CheckOp': 'IS NULL', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'f', 'Column': 'g'}}}}}, 'Assuming': None, 'Where': None}
# ==================

# %%
query = """PREDICT user.id
           FOR EACH user.id WHERE (NOT a.b == 10 AND c.d LIKE "e") OR NOT f.g IS NULL
           ASSUMING inf.age > 18
           WHERE ind.g == 100;"""
parse_query(query)
# Out:
# === Input Query ===
# PREDICT user.id
#            FOR EACH user.id WHERE (NOT a.b == 10 AND c.d LIKE "e") OR NOT f.g IS NULL
#            ASSUMING inf.age > 18
#            WHERE ind.g == 100;
# === Parse Tree ===
#   Rule: query
#   Rule: predict
#   Terminal: PREDICT (PREDICT)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: for_each
#   Terminal: FOR EACH (FOR_EACH)
#   Terminal: user (ID)
#   Terminal: . (DOT)
#   Terminal: id (ID)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Terminal: ( (OPEN_PAREN)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: a (ID)
#   Terminal: . (DOT)
#   Terminal: b (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 10 (INT)
#   Terminal: AND (AND)
#   Rule: expr_term
#   Rule: condition
#   Terminal: c (ID)
#   Terminal: . (DOT)
#   Terminal: d (ID)
#   Rule: str_condition
#   Terminal: LIKE (STR_COMP_OP)
#   Terminal: "e" (STRING)
#   Terminal: ) (CLOSE_PAREN)
#   Terminal: OR (OR)
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: NOT (NOT)
#   Terminal: f (ID)
#   Terminal: . (DOT)
#   Terminal: g (ID)
#   Rule: null_check_condition
#   Terminal: IS NULL (NULL_CHECK_OP)
#   Rule: assuming
#   Terminal: ASSUMING (ASSUMING)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: inf (ID)
#   Terminal: . (DOT)
#   Terminal: age (ID)
#   Rule: num_condition
#   Terminal: > (NUM_COMP_OP)
#   Terminal: 18 (INT)
#   Rule: where
#   Terminal: WHERE (WHERE)
#   Rule: expr_or
#   Rule: expr_and
#   Rule: expr_term
#   Rule: condition
#   Terminal: ind (ID)
#   Terminal: . (DOT)
#   Terminal: g (ID)
#   Rule: num_condition
#   Terminal: == (NUM_COMP_OP)
#   Terminal: 100 (INT)
#   Terminal: ; (SEMI_COLUMN)
# {'Predict': {'QType': 'predict', 'PredType': 'id_dot_id', 'Aggregation': None, 'Condition': None, 'Table': 'user', 'Column': 'id', 'RankTop': False, 'K': None, 'Classify': False}, 'ForEach': {'QType': 'for_each', 'Table': 'user', 'Column': 'id', 'Where': {'QType': 'where', 'Expr': {'Op': 'OR', 'Left': {'Op': 'AND', 'Left': {'CType': 'num', 'CompOp': '==', 'N': '10', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'a', 'Column': 'b'}, 'Right': {'CType': 'str', 'CompOp': 'LIKE', 'String': '"e"', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'c', 'Column': 'd'}}, 'Right': {'CType': 'null', 'CheckOp': 'IS NULL', 'CondType': 'id_dot_id', 'NOT': True, 'Aggregation': None, 'Table': 'f', 'Column': 'g'}}}}, 'Assuming': {'QType': 'assuming', 'Expr': {'CType': 'num', 'CompOp': '>', 'N': '18', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'inf', 'Column': 'age'}}, 'Where': {'QType': 'where', 'Expr': {'CType': 'num', 'CompOp': '==', 'N': '100', 'CondType': 'id_dot_id', 'NOT': False, 'Aggregation': None, 'Table': 'ind', 'Column': 'g'}}}
# ==================
